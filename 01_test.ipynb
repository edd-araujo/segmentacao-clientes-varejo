# %% [markdown]
# <a href="https://colab.research.google.com/github/edd-araujo/segmentacao-clientes-varejo/blob/main/01_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Isso é um teste

# %%
print("Hello World")
